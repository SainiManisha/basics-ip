# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import numpy as np
import cv2 #OpenCV-Python
# %matplotlib inline
import matplotlib.pyplot as plt

# read the image and define the stepSize and window size 
# (width,height)
image = cv2.imread('C:/Users/Manisha/Desktop/Image_Dataset/messi.jpg') # your image path
tmp = image # for drawing a rectangle
stepSize = 200
(w_width, w_height) = (200, 200) # window size
for x in range(0, image.shape[1] - w_width , stepSize):
   for y in range(0, image.shape[0] - w_height, stepSize):
      window = image[x:x + w_width, y:y + w_height, :]
      
# classify content of the window with your classifier and  
# determine if the window includes an object (cell) or not
      # draw window on image
      cv2.rectangle(tmp, (x, y), (x + w_width, y + w_height), (255, 0, 0), 2) # draw rectangle on image
      plt.imshow(np.array(tmp).astype('uint8'))
# show all windows
plt.show()

# %%
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
# pre-built and pre-trained deep learning VGG16 model
base_model = VGG16(weights='imagenet', include_top=True)
for i, layer in enumerate(base_model.layers):
 print(i, layer.name, layer.output_shape)
# extract features from block4_pool block
model =Model(input=base_model.input, output=base_model.get_layer('block4_pool').output)
# Out:
# Using TensorFlow backend.
# 0 input_1 (None, 224, 224, 3)
# 1 block1_conv1 (None, 224, 224, 64)
# 2 block1_conv2 (None, 224, 224, 64)
# 3 block1_pool (None, 112, 112, 64)
# 4 block2_conv1 (None, 112, 112, 128)
# 5 block2_conv2 (None, 112, 112, 128)
# 6 block2_pool (None, 56, 56, 128)
# 7 block3_conv1 (None, 56, 56, 256)
# 8 block3_conv2 (None, 56, 56, 256)
# 9 block3_conv3 (None, 56, 56, 256)
# 10 block3_pool (None, 28, 28, 256)
# 11 block4_conv1 (None, 28, 28, 512)
# 12 block4_conv2 (None, 28, 28, 512)
# 13 block4_conv3 (None, 28, 28, 512)
# 14 block4_pool (None, 14, 14, 512)
# 15 block5_conv1 (None, 14, 14, 512)
# 16 block5_conv2 (None, 14, 14, 512)
# 17 block5_conv3 (None, 14, 14, 512)
# 18 block5_pool (None, 7, 7, 512)
# 19 flatten (None, 25088)
# 20 fc1 (None, 4096)
# 21 fc2 (None, 4096)
# 22
# ...

# %%
#img_path ='C:/Users/Manisha/Desktop/Testing/1.png'
#img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(window )
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# get the features from this b

# get the features from this block
features = model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-ae51d760d548> in <module>()
#       7
#       8 # get the features from this block
# ----> 9 features = model.predict(x)
#
# ~\Anaconda3\envs\deeplearning\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1147                              'argument.')
#    1148         # Validate user data.
# -> 1149         x, _, _ = self._standardize_user_data(x)
#    1150         if self.stateful:
#    1151             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~\Anaconda3\envs\deeplearning\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# ...

# %%
import numpy as np
import cv2 #OpenCV-Python
# Load an image
features_1 = cv2.HuMoments(window)
print(features_1)
features_1.shape
# Out:
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]
# (7, 1)

# %%
import numpy as np
import cv2 #OpenCV-Python
# Load an image
image = cv2.imread('C:/Users/Manisha/Desktop/Testing/1.png')
image_1 = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
features_1 = cv2.HuMoments(cv2.moments(image_1)).flatten()
print(features_1)
features_1.shape
# Out:
# [ 8.65377232e-04  1.20413455e-07  4.83819164e-13  3.03371777e-14
#  -2.72358131e-27  8.33803730e-18  2.46792431e-27]
# (7,)

# %%
from skimage.feature import hog
import numpy as np

image_height = 48
image_width = 48
window_size = 24
window_step = 6

def sliding_hog_windows(image):
    hog_vector = []
    for y in xrange(0, image_height, window_step):
        for x in xrange(0, image_width, window_step):
            window = image[y:y+window_size, x:x+window_size]
            hog_vector.extend(hog(window, orientations=8, pixels_per_cell=(8, 8),
                                            cells_per_block=(1, 1), visualise=False))
    return hog_vector
    
#image = np.load('image.npy')
hog_vector = sliding_hog_windows(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4d518c847ec5> in <module>()
#      18
#      19 #image = np.load('image.npy')
# ---> 20 hog_vector = sliding_hog_windows(image)
#
# <ipython-input-11-4d518c847ec5> in sliding_hog_windows(image)
#      10 def sliding_hog_windows(image):
#      11     hog_vector = []
# ---> 12     for y in xrange(0, image_height, window_step):
#      13         for x in xrange(0, image_width, window_step):
#      14             window = image[y:y+window_size, x:x+window_size]
#
# NameError: name 'xrange' is not defined

# %%
image = cv2.imread('C:/Users/Manisha/Desktop/Image_Dataset/messi.jpg') # your image path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ddc6a0b8773> in <module>()
# ----> 1 image = cv2.imread('C:/Users/Manisha/Desktop/Image_Dataset/messi.jpg') # your image path
#
# NameError: name 'cv2' is not defined

# %%
import cv2
resize_img = cv2.resize(image  , (224, 224))

# %%
image1 = cv2.imread('C:/Users/Manisha/Desktop/Ant.1.jpg') # your image path

# %%
import cv2
resize_img = cv2.resize(image  , (224, 224))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import numpy as np
import cv2 #OpenCV-Python
# %matplotlib inline
import matplotlib.pyplot as plt

# read the image and define the stepSize and window size 
# (width,height)
image = cv2.imread('C:/Users/Manisha/Desktop/Ant.1.jpg') # your image path
resize_img = cv2.resize(image  , (500, 500))
tmp = resize_img# for drawing a rectangle
stepSize = 200
(w_width, w_height) = (300, 300) # window size
for x in range(0, resize_img.shape[1] - w_width , stepSize):
   for y in range(0, resize_img.shape[0] - w_height, stepSize):
      window = resize_img[x:x + w_width, y:y + w_height, :]
      
# classify content of the window with your classifier and  
# determine if the window includes an object (cell) or not
      # draw window on image
      cv2.rectangle(tmp, (x, y), (x + w_width, y + w_height), (255, 0, 0), 2) # draw rectangle on image
      plt.imshow(np.array(tmp).astype('uint8'))
# show all windows
plt.show()

# %%
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
# pre-built and pre-trained deep learning VGG16 model
base_model = VGG16(weights='imagenet', include_top=True)
for i, layer in enumerate(base_model.layers):
 print(i, layer.name, layer.output_shape)
# extract features from block4_pool block
model =Model(input=base_model.input, output=base_model.get_layer('block4_pool').output)
# Out:
# Using TensorFlow backend.
# 0 input_1 (None, 224, 224, 3)
# 1 block1_conv1 (None, 224, 224, 64)
# 2 block1_conv2 (None, 224, 224, 64)
# 3 block1_pool (None, 112, 112, 64)
# 4 block2_conv1 (None, 112, 112, 128)
# 5 block2_conv2 (None, 112, 112, 128)
# 6 block2_pool (None, 56, 56, 128)
# 7 block3_conv1 (None, 56, 56, 256)
# 8 block3_conv2 (None, 56, 56, 256)
# 9 block3_conv3 (None, 56, 56, 256)
# 10 block3_pool (None, 28, 28, 256)
# 11 block4_conv1 (None, 28, 28, 512)
# 12 block4_conv2 (None, 28, 28, 512)
# 13 block4_conv3 (None, 28, 28, 512)
# 14 block4_pool (None, 14, 14, 512)
# 15 block5_conv1 (None, 14, 14, 512)
# 16 block5_conv2 (None, 14, 14, 512)
# 17 block5_conv3 (None, 14, 14, 512)
# 18 block5_pool (None, 7, 7, 512)
# 19 flatten (None, 25088)
# 20 fc1 (None, 4096)
# 21 fc2 (None, 4096)
# 22 predictions (None, 1000)
# ...

# %%
import numpy as np
import glob
import numpy as np
#img_path ='C:/Users/Manisha/Desktop/Testing/1.png'
#img = image.load_img(img_path, target_size=(224, 224))

#x = image.img_to_array(window )
#x = np.expand_dims(x, axis=0)
x = preprocess_input(windows)
# get the features from this b

# get the features from this block
features = model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-cc8f6c9dcc69> in <module>()
#       7 #x = image.img_to_array(window )
#       8 #x = np.expand_dims(x, axis=0)
# ----> 9 x = preprocess_input(windows)
#      10 # get the features from this b
#      11
#
# NameError: name 'windows' is not defined

# %%
resize_img.shape
# Out:
# (500, 500, 3)

# %%
window.shape
# Out:
# (200, 200, 3)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import numpy as np
import cv2 #OpenCV-Python
# %matplotlib inline
import matplotlib.pyplot as plt

# read the image and define the stepSize and window size 
# (width,height)
image = cv2.imread('C:/Users/Manisha/Desktop/Ant.1.jpg') # your image path
resize_img = cv2.resize(image  , (500, 500))
tmp = resize_img# for drawing a rectangle
stepSize = 200
(w_width, w_height) = (200, 200) # window size
for x in range(0, resize_img.shape[1] - w_width , stepSize):
   for y in range(0, resize_img.shape[0] - w_height, stepSize):
      window = resize_img[x:x + w_width, y:y + w_height, :]
      
# classify content of the window with your classifier and  
# determine if the window includes an object (cell) or not
      # draw window on image
      cv2.rectangle(tmp, (x, y), (x + w_width, y + w_height), (255, 0, 0), 2) # draw rectangle on image
      plt.imshow(np.array(tmp).astype('uint8'))
# show all windows
plt.show()


import numpy as np
import glob
import numpy as np
#img_path ='C:/Users/Manisha/Desktop/Testing/1.png'
#img = image.load_img(img_path, target_size=(224, 224))

#x = image.img_to_array(window )
#x = np.expand_dims(x, axis=0)
x = preprocess_input(windows)
# get the features from this b

# get the features from this block
features = model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5ba17dc7f518> in <module>()
#      36 #x = image.img_to_array(window )
#      37 #x = np.expand_dims(x, axis=0)
# ---> 38 x = preprocess_input(windows)
#      39 # get the features from this b
#      40
#
# NameError: name 'windows' is not defined

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import numpy as np
import cv2 #OpenCV-Python
# %matplotlib inline
import matplotlib.pyplot as plt


windowsz=[]

# read the image and define the stepSize and window size 
# (width,height)
image = cv2.imread('C:/Users/Manisha/Desktop/Ant.1.jpg') # your image path
resize_img = cv2.resize(image  , (400, 400))
tmp = resize_img# for drawing a rectangle
stepSize = 200
(w_width, w_height) = (200, 200) # window size
for x in range(0, resize_img.shape[1] - w_width , stepSize):
   for y in range(0, resize_img.shape[0] - w_height, stepSize):
      window = resize_img[x:x + w_width, y:y + w_height, :]
      
# classify content of the window with your classifier and  
# determine if the window includes an object (cell) or not
      # draw window on image
      cv2.rectangle(tmp, (x, y), (x + w_width, y + w_height), (255, 0, 0), 2) # draw rectangle on image
      plt.imshow(np.array(tmp).astype('uint8'))
# show all windows
plt.show()


windowz.append(windows)
   


import numpy as np
import glob
import numpy as np
#img_path ='C:/Users/Manisha/Desktop/Testing/1.png'
#img = image.load_img(img_path, target_size=(224, 224))

#x = image.img_to_array(window )
#x = np.expand_dims(x, axis=0)
x = preprocess_input(windowsz)
# get the features from this b

# get the features from this block
features = model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-0f8c6b806ee6> in <module>()
#      31
#      32
# ---> 33 windowz.append(windows)
#      34
#      35
#
# NameError: name 'windowz' is not defined

# %%
print(window)
# Out:
# [[[255   0   0]
#   [255   0   0]
#   [255   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]
#
#  [[255   0   0]
#   [255   0   0]
#   [255   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]
#
#  [[255   0   0]
#   [255   0   0]
#   [ 21  22  32]
#   ...
#   [ 39  40  40]
#   [ 41  42  42]
#   [255   0   0]]
#
#  ...
#
#  [[255   0   0]
#   [255   0   0]
#   [165 159 178]
#   ...
#   [162 158 169]
#   [162 158 169]
#   [255   0   0]]
#
#  [[255   0   0]
#   [255   0   0]
#   [164 158 177]
#   ...
#   [162 158 170]
#   [162 158 170]
#   [255   0   0]]
#
#  [[255   0   0]
#   [255   0   0]
#   [255   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]]

# %%
import numpy as np
import glob
import numpy as np
#img_path ='C:/Users/Manisha/Desktop/Testing/1.png'
#img = image.load_img(img_path, target_size=(224, 224))

#x = image.img_to_array(window )
#x = np.expand_dims(x, axis=0)
x = preprocess_input(windows)
# get the features from this b

# get the features from this block
features = model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-cc8f6c9dcc69> in <module>()
#       7 #x = image.img_to_array(window )
#       8 #x = np.expand_dims(x, axis=0)
# ----> 9 x = preprocess_input(windows)
#      10 # get the features from this b
#      11
#
# NameError: name 'windows' is not defined

# %%
import numpy as np
import glob
import numpy as np
print(window)

window=np.array(window)

#img_path ='C:/Users/Manisha/Desktop/Testing/1.png'
#img = image.load_img(img_path, target_size=(224, 224))

#x = image.img_to_array(window )
#x = np.expand_dims(x, axis=0)
x = preprocess_input(windowsz)
# get the features from this b

# get the features from this block
features = model.predict(x)
# Out:
# [[[255   0   0]
#   [255   0   0]
#   [255   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]
#
#  [[255   0   0]
#   [255   0   0]
#   [255   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]
#
#  [[255   0   0]
#   [255   0   0]
#   [ 21  22  32]
#   ...
#   [ 39  40  40]
#   [ 41  42  42]
#   [255   0   0]]
#
#  ...
#
#  [[255   0   0]
#   [255   0   0]
#   [165 159 178]
#   ...
#   [162 158 169]
#   [162 158 169]
#   [255   0   0]]
#
#  [[255   0   0]
#   [255   0   0]
#   [164 158 177]
#   ...
#   [162 158 170]
#   [162 158 170]
#   [255   0   0]]
#
#  [[255   0   0]
#   [255   0   0]
#   [255   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-a20ac4a4d709> in <module>()
#      11 #x = image.img_to_array(window )
# ...
